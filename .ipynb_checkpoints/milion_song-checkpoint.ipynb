# %% [markdown]
# ## Strategy
#
# 1. collect the 10,000 songs data
# 2. in billboard top 100 or popularity, label it by bool value
# 3. use some machine learning to predict weather the songs are in top100 or not.

# %% [markdown]
# ## Collect the data

# %%
import pandas as pd
import random
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv("tracks_per_year.txt", sep = "<SEP>", header=None)
df.columns=["year", "track_id", "artist", "song"]
# Out:
# /Users/kentakawajiri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df_9010 = df[(df.year >= 1990) & (df.year <= 2010)] //

# %%
list(df_9010)
# Out:
# ['year', 'track_id', 'artist', 'song']

# %%
# Out:
# 2007    39414
# 2006    37546
# 2005    34960
# 2008    34770
# 2009    31051
# 2004    29618
# 2003    27389
# 2002    23472
# 2001    21604
# 2000    19293
# 1999    18262
# 1998    15858
# 1997    15182
# 1996    14135
# 1995    13260
# 1994    12127
# 1993    10529
# 1992     9547
# 2010     9397
# 1991     8650
# 1990     7258
# Name: year, dtype: int64

# %%
random.sample(list(df_9010.index), 10000)
# Out:
# [447159,
#  82753,
#  326466,
#  469295,
#  479266,
#  410281,
#  301688,
#  219856,
#  191652,
#  515539,
#  494421,
#  299793,
#  376720,
#  466610,
#  119266,
#  349715,
#  158819,
#  349385,
#  225983,
#  389504,
#  253326,
#  287179,
#  167115,
#  282955,
#  494489,
#  364533,
#  178106,
#  495114,
#  271664,
#  338367,
#  267849,
#  367078,
#  172598,
#  122352,
#  455290,
#  489941,
#  370957,
#  135868,
#  322475,
#  244177,
#  334973,
#  287101,
#  303585,
#  437561,
#  338477,
#  134275,
#  378139,
#  271275,
#  262117,
#  83023,
#  373818,
#  452636,
#  456566,
#  391100,
#  362863,
#  350662,
#  157793,
#  129481,
#  256823,
#  434358,
#  125988,
#  236055,
#  144854,
#  216759,
#  240795,
#  430800,
#  503831,
#  515118,
#  314671,
#  184853,
#  268492,
#  276049,
#  339724,
#  477534,
#  506571,
#  411272,
#  100132,
#  109375,
#  433389,
#  109176,
#  454869,
#  413937,
#  195779,
#  131747,
#  142771,
#  127983,
#  461977,
#  197097,
#  137308,
#  173729,
#  152670,
#  207459,
#  338650,
#  171216,
#  468194,
#  238655,
#  358863,
#  397585,
#  162861,
#  376649,
#  186740,
#  467870,
#  439726,
#  113988,
#  312516,
#  347802,
#  414517,
#  474767,
#  480872,
#  487122,
#  445207,
#  449970,
#  115719,
#  254541,
#  234563,
#  379149,
#  237971,
#  91046,
#  321846,
#  458247,
#  183433,
#  160757,
#  278445,
#  369818,
#  339833,
#  254927,
#  196842,
#  182359,
#  411709,
#  371047,
#  174147,
#  132663,
#  341571,
#  371762,
#  215058,
#  277914,
#  88887,
#  356607,
#  244264,
#  286189,
#  496809,
#  229313,
#  348130,
#  239635,
#  289292,
#  431630,
#  173832,
#  236971,
#  227949,
#  428237,
#  226739,
#  487809,
#  180287,
#  322413,
#  490239,
#  454607,
#  479318,
#  320653,
#  462344,
#  245624,
#  296606,
#  269651,
#  449173,
#  343945,
#  197424,
#  250757,
#  512622,
#  159997,
#  146665,
#  226473,
#  235100,
#  295677,
#  451507,
#  148358,
#  140115,
#  129202,
#  299918,
#  257683,
#  459297,
#  122685,
#  107188,
#  322945,
#  453981,
#  395288,
#  327841,
#  406111,
#  292437,
#  304888,
#  385766,
#  284481,
#  282554,
#  266477,
#  397813,
#  168503,
#  508290,
#  241722,
#  417911,
#  306506,
#  318104,
#  345632,
#  406168,
#  341059,
#  156849,
#  419891,
#  227117,
#  302039,
#  85168,
#  288074,
#  394450,
#  381459,
#  281140,
#  422997,
#  336225,
#  148913,
#  402415,
#  285458,
#  227807,
#  514138,
#  121781,
#  97469,
#  257940,
#  492796,
#  390294,
#  390933,
#  92774,
#  259338,
#  367560,
#  322201,
#  112923,
#  372689,
#  220493,
#  102540,
#  408948,
#  167107,
#  303855,
#  139690,
#  373045,
#  338587,
#  220199,
#  358213,
#  401503,
#  138664,
#  137492,
#  166273,
#  187576,
#  185842,
#  484392,
#  315109,
#  336854,
#  236542,
#  260413,
#  290964,
#  457687,
#  342734,
#  220419,
#  360692,
#  198312,
#  367388,
#  99438,
#  367469,
#  479107,
#  111369,
#  259423,
#  362205,
#  223470,
#  429726,
#  105898,
#  148685,
#  98454,
#  401424,
#  98112,
#  455930,
#  108281,
#  344514,
#  491790,
#  365378,
#  272595,
#  199438,
#  286040,
#  98788,
#  465121,
#  289458,
#  446832,
#  185003,
#  394515,
#  448343,
#  448047,
#  458557,
#  214178,
#  263693,
#  257663,
#  287854,
#  199245,
#  503589,
#  321479,
#  320123,
#  206282,
#  494950,
#  183240,
#  158940,
#  110974,
#  409123,
#  141973,
#  510004,
#  428473,
#  408927,
#  304363,
#  145557,
#  477586,
#  369968,
#  256884,
#  444090,
#  103443,
#  468204,
#  281018,
#  172118,
#  310347,
#  245196,
#  142868,
#  441636,
#  217125,
#  234691,
#  511236,
#  464268,
#  240484,
#  273850,
#  499776,
#  121871,
#  126131,
#  139871,
#  116400,
#  221809,
#  307178,
#  490412,
#  265637,
#  401589,
#  376004,
#  396657,
#  99549,
#  208070,
#  134679,
#  163101,
#  279995,
#  399962,
#  106714,
#  459370,
#  264215,
#  229591,
#  404876,
#  365336,
#  454997,
#  312136,
#  163082,
#  118434,
#  97520,
#  293247,
#  291040,
#  104955,
#  133182,
#  162338,
#  290477,
#  505744,
#  309960,
#  421181,
#  291563,
#  274742,
#  152547,
#  411459,
#  195462,
#  155290,
#  94392,
#  440429,
#  291676,
#  300328,
#  444265,
#  369492,
#  413784,
#  367538,
#  119628,
#  450124,
#  97674,
#  268433,
#  166476,
#  134502,
#  167689,
#  220612,
#  447106,
#  102162,
#  342884,
#  174850,
#  179297,
#  265276,
#  323874,
#  216398,
#  88172,
#  470846,
#  375234,
#  471476,
#  269488,
#  104817,
#  97557,
#  418456,
#  335838,
#  214083,
#  488540,
#  178516,
#  323854,
#  467658,
#  498799,
#  218833,
#  135632,
#  277103,
#  455027,
#  412660,
#  500169,
#  257043,
#  100112,
#  507668,
#  341331,
#  384897,
#  478567,
#  388934,
#  441529,
#  404471,
#  133778,
#  233868,
#  332678,
#  221616,
#  393356,
#  231866,
#  506568,
#  319894,
#  486163,
#  149615,
#  284741,
#  325710,
#  301370,
#  84634,
#  375978,
#  184138,
#  452741,
#  151989,
#  435078,
#  165591,
#  282527,
#  402178,
#  463023,
#  259484,
#  364049,
#  86183,
#  333475,
#  446381,
#  83844,
#  162115,
#  391642,
#  101515,
#  317124,
#  504589,
#  315521,
#  179968,
#  491382,
#  405767,
#  387281,
#  413818,
#  461477,
#  402909,
#  286881,
#  406087,
#  311156,
#  326966,
#  309198,
#  493081,
#  94642,
#  82624,
#  473880,
#  315641,
#  88541,
#  427988,
#  497213,
#  352952,
#  428774,
#  84734,
#  443855,
#  351918,
#  216172,
#  108447,
#  101029,
#  218271,
#  290140,
#  483149,
#  204187,
#  232215,
#  277735,
#  250208,
#  438539,
#  459464,
#  150618,
#  144144,
#  275974,
#  512948,
#  488097,
#  205727,
#  167605,
#  328480,
#  420254,
#  321357,
#  384315,
#  345980,
#  182965,
#  183761,
#  500668,
#  515555,
#  169719,
#  461227,
#  367205,
#  151127,
#  275062,
#  237692,
#  207921,
#  173881,
#  217327,
#  456278,
#  313790,
#  163529,
#  258293,
#  130094,
#  176978,
#  404707,
#  508248,
#  124054,
#  348273,
#  442047,
#  498082,
#  305951,
#  451224,
#  401399,
#  322093,
#  107149,
#  491954,
#  118767,
#  456596,
#  111568,
#  213467,
#  91888,
#  148301,
#  241915,
#  441164,
#  120408,
#  350427,
#  149396,
#  364353,
#  511214,
#  304513,
#  405530,
#  220986,
#  363716,
#  470513,
#  159493,
#  364785,
#  113622,
#  334334,
#  432836,
#  267997,
#  263214,
#  193664,
#  462879,
#  225703,
#  431611,
#  257071,
#  320450,
#  336369,
#  83787,
#  198252,
#  203730,
#  477309,
#  177718,
#  345251,
#  357366,
#  261822,
#  334338,
#  217629,
#  160873,
#  246126,
#  176647,
#  365946,
#  363436,
#  335112,
#  160185,
#  404300,
#  253199,
#  456336,
#  200979,
#  390317,
#  116089,
#  498352,
#  377724,
#  250802,
#  423096,
#  475073,
#  236895,
#  358364,
#  87454,
#  466241,
#  433683,
#  481207,
#  90838,
#  157193,
#  167329,
#  374032,
#  233825,
#  481911,
#  166680,
#  500674,
#  146165,
#  432772,
#  360912,
#  256372,
#  280270,
#  365949,
#  149236,
#  476169,
#  410239,
#  358856,
#  186250,
#  231757,
#  272678,
#  186066,
#  169574,
#  206630,
#  241775,
#  261099,
#  259992,
#  362657,
#  288276,
#  409876,
#  157562,
#  322547,
#  85774,
#  156363,
#  187543,
#  278047,
#  389381,
#  248463,
#  215353,
#  324925,
#  89396,
#  115355,
#  114595,
#  468221,
#  377133,
#  193648,
#  463471,
#  230384,
#  89350,
#  492775,
#  378234,
#  493440,
#  147795,
#  375799,
#  469841,
#  331389,
#  408527,
#  485651,
#  357467,
#  222270,
#  138199,
#  95773,
#  452012,
#  214811,
#  220431,
#  249839,
#  265744,
#  331204,
#  392947,
#  218022,
#  157956,
#  482551,
#  109305,
#  321184,
#  214656,
#  483368,
#  136421,
#  430759,
#  105160,
#  99715,
#  287704,
#  248070,
#  505525,
#  211132,
#  469513,
#  366654,
#  200062,
#  325777,
#  191883,
#  328631,
#  177529,
#  514852,
#  506873,
#  475305,
#  388281,
#  424226,
#  215551,
#  96809,
#  499322,
#  504826,
#  498859,
#  420050,
#  279738,
#  323376,
#  314048,
#  468998,
#  513325,
#  349031,
#  242507,
#  156036,
#  113002,
#  418058,
#  466471,
#  281481,
#  330027,
#  465220,
#  494306,
#  429341,
#  190931,
#  117433,
#  126047,
#  172273,
#  187611,
#  378955,
#  184425,
#  262691,
#  387860,
#  182386,
#  494041,
#  347262,
#  485058,
#  111132,
#  338084,
#  443864,
#  365305,
#  373708,
#  118100,
#  298184,
#  515190,
#  432575,
#  153379,
#  490171,
#  215384,
#  266866,
#  407007,
#  454332,
#  232901,
#  413287,
#  367036,
#  128208,
#  277672,
#  257497,
#  367162,
#  132313,
#  265878,
#  232606,
#  297901,
#  119526,
#  208974,
#  495685,
#  176840,
#  469210,
#  484706,
#  484659,
#  97712,
#  170988,
#  265833,
#  83535,
#  101414,
#  161661,
#  213456,
#  403285,
#  380453,
#  128214,
#  286145,
#  407074,
#  355575,
#  442974,
#  439089,
#  270170,
#  462915,
#  428886,
#  210881,
#  424005,
#  281073,
#  132375,
#  352096,
#  514147,
#  335722,
#  90132,
#  467075,
#  457039,
#  270677,
#  464030,
#  259121,
#  411625,
#  432060,
#  354781,
#  212142,
#  504272,
#  475845,
#  284001,
#  416881,
#  217887,
#  483470,
#  360678,
#  315551,
#  159368,
#  364064,
#  124466,
#  483063,
#  320250,
#  299926,
#  427617,
#  360515,
#  453393,
#  333008,
#  494397,
#  488585,
#  465240,
#  260795,
#  514999,
#  403716,
#  339232,
#  411437,
#  228746,
#  193131,
#  198985,
#  350260,
#  353618,
#  278785,
#  243614,
#  205702,
#  372713,
#  188408,
#  392677,
#  103258,
#  397554,
#  328013,
#  333778,
#  266402,
#  402779,
#  117732,
#  265477,
#  470812,
#  146028,
#  262357,
#  380693,
#  156396,
#  268612,
#  398669,
#  316684,
#  188385,
#  409453,
#  200325,
#  311045,
#  145110,
#  336411,
#  353595,
#  107132,
#  234378,
#  95860,
#  468621,
#  476178,
#  305664,
#  430144,
#  212674,
#  345009,
#  356886,
#  255314,
#  508938,
#  334862,
#  234723,
#  204129,
#  191764,
#  413354,
#  139341,
#  321512,
#  323617,
#  320878,
#  314771,
#  380485,
#  267748,
#  196726,
#  371571,
#  371146,
#  184980,
#  115544,
#  431558,
#  458515,
#  202570,
#  328901,
#  181154,
#  508005,
#  138106,
#  168255,
#  343021,
#  113905,
#  439029,
#  357106,
#  141579,
#  507308,
#  154499,
#  309419,
#  478936,
#  349016,
#  397966,
#  100456,
#  402608,
#  153158,
#  311091,
#  362833,
#  338101,
#  173133,
#  415382,
#  113379,
#  433739,
#  371885,
#  435442,
#  391703,
#  307084,
#  292897,
#  130082,
#  92257,
#  219520,
#  453422,
#  510009,
#  170579,
#  286442,
#  385059,
#  171906,
#  327878,
#  109035,
#  368237,
#  415746,
#  457102,
#  343359,
#  306109,
#  450760,
#  208920,
#  173860,
#  135404,
#  435750,
#  384854,
#  265796,
#  231711,
#  450195,
#  168708,
#  223047,
#  234948,
#  125657,
#  459601,
#  337529,
#  91012,
#  265948,
#  412736,
#  448748,
#  256188,
#  175670,
#  199456,
#  203750,
#  164453,
#  437966,
#  210149,
#  120966,
#  340788,
#  443798,
#  351548,
#  478286,
#  301932,
#  229569,
#  305214,
#  365074,
#  347240,
#  297002,
#  158277,
#  329562,
#  209902,
#  213285,
#  335372,
#  375762,
#  501552,
#  211815,
#  475835,
#  380906,
#  502782,
#  503045,
#  166145,
#  105484,
#  512054,
#  89705,
#  119088,
#  478734,
#  419065,
#  439863,
#  ...]
